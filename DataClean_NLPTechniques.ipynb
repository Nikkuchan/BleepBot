# %% [markdown]
# <a href="https://colab.research.google.com/github/Nikkuchan/BleepBot/blob/main/DataClean_NLPTechniques.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import nltk
import string
from nltk.tokenize import word_tokenize
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
pd.set_option('display.max_colwidth', 100)
# %matplotlib inline

# %%
with open('/content/transcribev2.csv') as f:
    df = pd.read_csv(f)
f.close()

# %%
df
# Out:
#                                 transcribe  confi_val
# 0                            Fox A1 kanina   0.679135
# 1                  Wala na fuck Talo na eh   0.729727
# 2        nakakasawa pagmumukha mo Fuck you   0.844305
# 3                Fuck you kung sino ka man   0.939141
# 4                  Fuck you using mo naman   0.737964
# ..                                     ...        ...
# 546                 tsamba panalo fuck you   0.636753
# 547                    talo kasi fucker ka   0.829933
# 548  ayusin mo yung pag assist mo fuck you   0.701956
# 549                       Fuck you go away   0.942674
# 550     palitan mo na computer mo fuck you   0.712989
#
# [551 rows x 2 columns]

# %%
checkpunct = df.iloc[122]
checkpunct
# Out:
# transcribe    pre Ba't di mo ko nirevive Tang ina
# confi_val                                0.691517
# Name: 122, dtype: object

# %%
#remove punctuations using str.replace regex (ba't -> bat)
df['transcribe'] = df['transcribe'].str.replace(r'[^\w\s]+', '')
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: FutureWarning: The default value of regex will change from True to False in a future version.

# %%
checkpunct = df.iloc[122]
checkpunct
# Out:
# transcribe    pre Bat di mo ko nirevive Tang ina
# confi_val                               0.691517
# Name: 122, dtype: object

# %%
#convert to transcribe column to lower case 
df['transcribe'] = df['transcribe'].str.lower()

# %%
df
# Out:
#                                 transcribe  confi_val
# 0                            fox a1 kanina   0.679135
# 1                  wala na fuck talo na eh   0.729727
# 2        nakakasawa pagmumukha mo fuck you   0.844305
# 3                fuck you kung sino ka man   0.939141
# 4                  fuck you using mo naman   0.737964
# ..                                     ...        ...
# 546                 tsamba panalo fuck you   0.636753
# 547                    talo kasi fucker ka   0.829933
# 548  ayusin mo yung pag assist mo fuck you   0.701956
# 549                       fuck you go away   0.942674
# 550     palitan mo na computer mo fuck you   0.712989
#
# [551 rows x 2 columns]

# %%
 nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
df['tokenized'] = df['transcribe'].apply(word_tokenize)
df
# Out:
#                                 transcribe  confi_val  \
# 0                            fox a1 kanina   0.679135
# 1                  wala na fuck talo na eh   0.729727
# 2        nakakasawa pagmumukha mo fuck you   0.844305
# 3                fuck you kung sino ka man   0.939141
# 4                  fuck you using mo naman   0.737964
# ..                                     ...        ...
# 546                 tsamba panalo fuck you   0.636753
# 547                    talo kasi fucker ka   0.829933
# 548  ayusin mo yung pag assist mo fuck you   0.701956
# 549                       fuck you go away   0.942674
# 550     palitan mo na computer mo fuck you   0.712989
#
#                                           tokenized
# 0                                 [fox, a1, kanina]
# 1                    [wala, na, fuck, talo, na, eh]
# 2           [nakakasawa, pagmumukha, mo, fuck, you]
# 3                  [fuck, you, kung, sino, ka, man]
# ...

# %%
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
pip install nltk
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
new_stopwords = ["akin","ako","mo","ka","tayo","ikaw","alin","amin",
                 "ay","bababa","dapat","ginawa","ginawang","bawat","ano",
                 "dahil","bilang","tama","na","nga","using","si","pati","ang",
                 "hala","pre","nag","edi","punta","pinupuntahan","lang","sa",
                 "mali","-","q","mong","date","busog","kayo","kayong","buka",
                 "ibubuka","nais","try","yung","katropa","gaya","ng","pic","bang",
                 "wala","pakita","computer","ambag","dito","nabawasan","bawas",
                 "footballer", "napaka","sayo","balota","bida","pietro","jett",
                 "mag-text","para","may","hindi","ni","ba","dalawa","salba","tutok",
                 "shadow", "install","ballaran","ito","mga","nalang","noh","baka",
                 "samin","mag","nasa","pa","masa","ata","po","ita","ga","kasi","eh",
                 "ol","nang","kang","naman","ko","tae","ata","atang","sana","kung","di",
                 "ah","much","pag"]
stpwrd = nltk.corpus.stopwords.words('english')
stpwrd.extend(new_stopwords)
df['removed_stopwords'] = df['tokenized'].apply(lambda x: [word for word in x if word not in stpwrd])

# %%
df
# Out:
#                                 transcribe  confi_val  \
# 0                            fox a1 kanina   0.679135
# 1                  wala na fuck talo na eh   0.729727
# 2        nakakasawa pagmumukha mo fuck you   0.844305
# 3                fuck you kung sino ka man   0.939141
# 4                  fuck you using mo naman   0.737964
# ..                                     ...        ...
# 546                 tsamba panalo fuck you   0.636753
# 547                    talo kasi fucker ka   0.829933
# 548  ayusin mo yung pag assist mo fuck you   0.701956
# 549                       fuck you go away   0.942674
# 550     palitan mo na computer mo fuck you   0.712989
#
#                                           tokenized  \
# 0                                 [fox, a1, kanina]
# 1                    [wala, na, fuck, talo, na, eh]
# 2           [nakakasawa, pagmumukha, mo, fuck, you]
# 3                  [fuck, you, kung, sino, ka, man]
# ...

# %%
df.to_csv('profanity_clean.csv')
